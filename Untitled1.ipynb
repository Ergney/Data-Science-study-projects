# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats

# %%
path = 'C:\\Users\\iodaa\\Documents\\one\\Data\\'

df = pd.read_csv(path+"CAvideos.csv")

# %% [markdown]
#     Датасет представляет собой статистику ютуба для северной америки.
#
#     Планирую исследовать влияние категории видео на просмотры\лайки\дизлайки\комментарии
#     Корреляции различных параметров.
#
#     Сперва поерхностно взглянем на данные

# %%
df.head(10)
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
# 5  0yIWz1XEeyc      17.14.11
# 6  _uM5kFfkhB8      17.14.11
# 7  2kyS6SvSYSE      17.14.11
# 8  JzCsM1vtn78      17.14.11
# 9  43sm-QwLcx4      17.14.11
#
#                                                title     channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                           I Dare You: GOING BALD!?          nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# 5  Jake Paul Says Alissa Violet CHEATED with LOGA...        DramaAlert
# 6             Vanoss Superhero School - New Students      VanossGaming
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40881 non-null  object
#  1   trending_date           40881 non-null  object
#  2   title                   40881 non-null  object
#  3   channel_title           40881 non-null  object
#  4   category_id             40881 non-null  int64
#  5   publish_time            40881 non-null  object
#  6   tags                    40881 non-null  object
#  7   views                   40881 non-null  int64
#  8   likes                   40881 non-null  int64
#  9   dislikes                40881 non-null  int64
#  10  comment_count           40881 non-null  int64
#  11  thumbnail_link          40881 non-null  object
#  12  comments_disabled       40881 non-null  bool
#  13  ratings_disabled        40881 non-null  bool
# ...

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %% [markdown]
# Как видно в датасете 16 столбцов и 40881 записей. Столбцы типа object для нас бесполезны, так как содержат различные нечисловые и не булевые характеристики видео (название\описание\ссылка и т д.) так же по ним нет возможности как-то сгрупировать видео. Так же иммется столбец category_id который по всей видимости относит соотносит видео с каким-то неизвестным нам списком категорий, отлично подходит для группировки.

# %% [markdown]
# Судя по минимальному и максимальному значению в выборке имются выбросы, которые могут негативно сказаться на анализе данных.
#
# Избавимся от них, отбросив все значения менее 0.1 квантиля и более 0.9

# %%
def vibrosi(atribut):
    data = df[atribut].loc[(df[atribut] >= df[atribut].quantile(0.05)) & (df[atribut] <= df[atribut].quantile(0.95))] 
    return data

# %%
df["views"] = vibrosi("views")
df["likes"] = vibrosi("likes")
df["dislikes"] = vibrosi("dislikes")
df["comment_count"] = vibrosi("comment_count")

# %%
df.describe()
# Out:
#         category_id         views          likes      dislikes  comment_count
# count  40881.000000  3.679300e+04   36794.000000  36911.000000   36824.000000
# mean      20.795553  6.754990e+05   21012.100016    738.257999    2677.036145
# std        6.775054  7.800468e+05   30187.640886   1094.798492    3507.909779
# min        1.000000  3.006100e+04     201.000000     13.000000      37.000000
# 25%       20.000000  1.599860e+05    2579.000000    112.000000     479.000000
# 50%       24.000000  3.712040e+05    8779.000000    301.000000    1299.000000
# 75%       24.000000  8.652950e+05   25177.000000    831.000000    3294.000000
# max       43.000000  4.090835e+06  165252.000000   6479.000000   19210.000000

# %% [markdown]
# Теперь проверим распределение различных величин (views, likes, dislikes, comment_count) из датасета.

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(15, 4)

ax1, ax2, ax3, ax4 = ax.flatten()

fig.set_size_inches(12, 8)
fig.subplots_adjust(wspace=0.4, hspace=0.4)

ax1.hist(df["views"], bins=15)
ax1.set_title("views")

ax2.hist(df["likes"], bins=15)
ax2.set_title("likes")

ax3.hist(df["dislikes"], bins=15)
ax3.set_title("dislikes")

ax4.hist(df["comment_count"], bins=15)
ax4.set_title("comment_count")

plt.show()

# %% [markdown]
# Как видно, все распределения не являются нормальными. Даже после удаления выбросов подавляюшее большинство имеет довольно малое количество просмотров лайков и т д.

# %%
# Out:
# (array([15936.,  7414.,  4006.,  2489.,  1677.,  1227.,   941.,   694.,
#           549.,   450.,   400.,   304.,   278.,   212.,   216.]),
#  array([  30061.        ,  300779.26666667,  571497.53333333,
#          842215.8       , 1112934.06666667, 1383652.33333333,
#         1654370.6       , 1925088.86666667, 2195807.13333333,
#         2466525.4       , 2737243.66666667, 3007961.93333333,
#         3278680.2       , 3549398.46666667, 3820116.73333333,
#         4090835.        ]),
#  <BarContainer object of 15 artists>)
